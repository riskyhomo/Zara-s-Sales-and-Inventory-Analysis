# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import itertools
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import matplotlib

# %%
# Import libraries
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_boston
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import train_test_split

# %%
invent_turnover_table = pd.read_csv('Outputs/invent_turnover_table.csv')
invent_turnover_table
# Out:
#       product_id  curr_liability  price   revenue  sales      stock  \
# 0         151926       207470.25  25.95   4333.65  167.0  49.049080
# 1         213413      1130087.70  19.95  15102.15  757.0  90.924559
# 2         310130       642825.05  12.95   7485.10  578.0  80.713821
# 3         455200        67627.10  29.95    718.80   24.0  15.360544
# 4         571044       300944.60  15.95   9426.45  591.0  38.903093
# ...          ...             ...    ...       ...    ...        ...
# 9226   999772605       101075.15  15.95   2918.85  183.0  73.686047
# 9227   999794342        74934.90  29.95    838.60   28.0  32.921053
# 9228   999816749       196332.15   5.95   2951.20  496.0  56.598628
# 9229   999862351       303173.85  25.95   3503.25  135.0  15.938608
# 9230   999936664       343291.85  15.95    972.95   61.0  29.243207
#
#       inventory_turnover         dsi
# 0               3.404753   27.314757
# 1               8.325583   11.170388
# ...

# %%
invent_turnover_table.drop(columns={'curr_liability', 'revenue'}, inplace=True)

# %%
sns.pairplot(invent_turnover_table)

# %% [markdown]
# ## Decision Tree
# ### Predict Stock

# %%
# Import libraries
from sklearn.tree import DecisionTreeRegressor
from sklearn import datasets
from sklearn.model_selection import cross_val_score

# %%
X = invent_turnover_table.drop(columns={'stock'})
y = invent_turnover_table['stock']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 29)

# %%
interaction = PolynomialFeatures(degree = 3, include_bias = False, interaction_only = True)
X_inter = interaction.fit_transform(X_train)

# %%
regr = DecisionTreeRegressor(random_state = 29)

model = regr.fit(X_train, y_train)

regr.score(X_test, y_test)
# Out:
# 0.9697352288192771

# %%
cross_val_score(regr, X, y, cv=10)
# Out:
# array([0.96601001, 0.96525075, 0.96825161, 0.96603928, 0.9582946 ,
#        0.97727205, 0.95527682, 0.96414766, 0.9800629 , 0.93010874])

# %%
y_pred = regr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(y_test, y_pred)
# Out:
# 3.4427912716639493

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_pred)
# Out:
# 90.63447792112362

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.9697352288192771

# %% [raw]
# from sklearn.model_selection import GridSearchCV
#
#
# param_grid = {'criterion':['mae', 'mse', 'friedman_mse'],
#               'splitter':['best', 'random'],
#               'max_depth':[None, 1,2,3,4,5,6,7,8,9],
#               'min_samples_split':[2,3,4,5,6,7,8,9],
#               'max_features':[None, 'auto', 'sqrt', 'log2']
#               }
#
# regr = GridSearchCV(DecisionTreeRegressor(), param_grid, cv=5)
#
# regr.fit(X_train, y_train)
#
# print (f'DecisionTree: Area under the ROC curve = {regr_performance}')

# %% [raw]
# regr.best_params_

# %% [raw]
# regr.prob

# %% [markdown]
# ### Predict Sales

# %%
X = invent_turnover_table.drop(columns={'sales'})
y = invent_turnover_table['sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 29)

# %%
interaction = PolynomialFeatures(degree = 3, include_bias = False, interaction_only = True)
X_inter = interaction.fit_transform(X_train)

# %%
regr = DecisionTreeRegressor(random_state = 29)

model = regr.fit(X_train, y_train)

regr.score(X_test, y_test)
# Out:
# 0.971295198366904

# %%
y_pred = regr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(y_test, y_pred)
# Out:
# 23.068024263431543

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_pred)
# Out:
# 10292.019497400346

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.971295198366904

# %% [markdown]
# ### Time

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import matplotlib
import datetime
from datetime import timedelta
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
products_final = pd.read_csv('Outputs/Products-final.csv')

# %%
products_final['initial_date'] = '5-1-2019'
products_final['initial_date'] = pd.to_datetime(products_final['initial_date'], format="%d-%m-%Y",)
products_final
# Out:
#          Unnamed: 0  product_id  block_id  family_id  subfamily_id  price  \
# 0                 0   612967398         0  744793598     325094680  39.95
# 1                 1   612967398         0  744793598     325094680  39.95
# 2                 2   612967398         0  744793598     325094680  39.95
# 3                 3   612967398         0  744793598     325094680  39.95
# 4                 4   612967398         0  744793598     325094680  39.95
# ...             ...         ...       ...        ...           ...    ...
# 3741856     3741856   608709148      2775  396066037     884647976  29.95
# 3741857     3741857   608709148      2775  396066037     884647976  29.95
# 3741858     3741858   608709148      2775  396066037     884647976  29.95
# 3741859     3741859   608709148      2775  396066037     884647976  29.95
# 3741860     3741860   608709148      2775  396066037     884647976  29.95
#
#          date_number     color_id      size_id  sales  stock initial_date
# ...

# %%
products_final.dtypes
# Out:
# Unnamed: 0               int64
# product_id               int64
# block_id                 int64
# family_id                int64
# subfamily_id             int64
# price                  float64
# date_number            float64
# color_id               float64
# size_id                float64
# sales                  float64
# stock                  float64
# initial_date    datetime64[ns]
# dtype: object

# %%
products_final['date_number'] = products_final['date_number'].apply(lambda x: pd.Timedelta(x,unit='d'))
#products_final['dummy_date'] = products_final['initial_date'] + temp

#products_final

# %%
products_final['dummy_date'] = products_final['initial_date'] + products_final['date_number']
products_final
# Out:
#          Unnamed: 0  product_id  block_id  family_id  subfamily_id  price  \
# 0                 0   612967398         0  744793598     325094680  39.95
# 1                 1   612967398         0  744793598     325094680  39.95
# 2                 2   612967398         0  744793598     325094680  39.95
# 3                 3   612967398         0  744793598     325094680  39.95
# 4                 4   612967398         0  744793598     325094680  39.95
# ...             ...         ...       ...        ...           ...    ...
# 3741856     3741856   608709148      2775  396066037     884647976  29.95
# 3741857     3741857   608709148      2775  396066037     884647976  29.95
# 3741858     3741858   608709148      2775  396066037     884647976  29.95
# 3741859     3741859   608709148      2775  396066037     884647976  29.95
# 3741860     3741860   608709148      2775  396066037     884647976  29.95
#
#         date_number     color_id      size_id  sales  stock initial_date  \
# ...

# %%
products_final = products_final.drop(columns={'Unnamed: 0','date_number', })

# %%
products_final.dtypes
# Out:
# product_id               int64
# block_id                 int64
# family_id                int64
# subfamily_id             int64
# price                  float64
# color_id               float64
# size_id                float64
# sales                  float64
# stock                  float64
# initial_date    datetime64[ns]
# dummy_date      datetime64[ns]
# dtype: object

# %%
products_final = products_final.set_index('dummy_date')

# %%
products_final['sales'].resample('W').mean().plot(figsize=(15, 6))

# %%
products_final['stock'].resample('W').mean().plot(figsize=(15, 6))

# %%
y = products_final['stock'].resample('W').mean()

# %%
y
# Out:
# dummy_date
# 2019-01-06    58.009681
# 2019-01-13    57.896536
# 2019-01-20    59.976733
# 2019-01-27    59.188071
# 2019-02-03    57.959811
# 2019-02-10    56.797409
# 2019-02-17    57.856887
# 2019-02-24    58.891696
# 2019-03-03    56.511963
# 2019-03-10    55.157417
# 2019-03-17    53.155392
# 2019-03-24    50.770296
# 2019-03-31    48.233706
# 2019-04-07    51.746747
# Name: stock, dtype: float64

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10
decomposition = sm.tsa.seasonal_decompose(y,freq=12,extrapolate_trend=3, model='additive')
fig = decomposition.plot()
plt.show()
plt.savefig('Outputs/tsa_seasona.png', dsi=900)

# %%
products_final = products_final.drop(columns={'initial_date'})

# %%
products_final = products_final.drop(columns={'block_id'})

# %%
products_final.head()
# Out:
#             product_id  family_id  subfamily_id  price     color_id  \
# dummy_date
# 2019-01-05   612967398  744793598     325094680  39.95  718368786.0
# 2019-01-05   612967398  744793598     325094680  39.95  718368786.0
# 2019-01-05   612967398  744793598     325094680  39.95  718368786.0
# 2019-01-05   612967398  744793598     325094680  39.95  718368786.0
# 2019-01-05   612967398  744793598     325094680  39.95  718368786.0
#
#                 size_id  sales  stock
# dummy_date
# 2019-01-05  182555396.0    0.0   45.0
# 2019-01-05  421635475.0    0.0   34.0
# 2019-01-05  558685710.0    5.0  161.0
# 2019-01-05  642148717.0    1.0   98.0
# 2019-01-05  674701524.0    0.0   75.0

# %% [raw]
# from pandas.plotting import autocorrelation_plot
#
# autocorrelation_plot(products_final)
# plt.show()
